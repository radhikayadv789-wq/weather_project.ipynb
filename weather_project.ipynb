# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("weather_data.csv")
data.head()
# Out:
#        Location            Date_Time  Temperature_C  Humidity_pct  \
# 0     San Diego  2024-01-14 21:12:46      10.683001     41.195754
# 1     San Diego  2024-05-17 15:22:10       8.734140     58.319107
# 2     San Diego  2024-05-11 09:30:59      11.632436     38.820175
# 3  Philadelphia  2024-02-26 17:32:39      -8.628976     54.074474
# 4   San Antonio  2024-04-29 13:23:51      39.808213     72.899908
#
#    Precipitation_mm  Wind_Speed_kmh
# 0          4.020119        8.233540
# 1          9.111623       27.715161
# 2          4.607511       28.732951
# 3          3.183720       26.367303
# 4          9.598282       29.898622
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Temperature_C'].plot(kind='hist', bins=20, title='Temperature_C')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data.shape
data.info()
data.describe()
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302162 entries, 0 to 302161
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Location          302162 non-null  object
#  1   Date_Time         302162 non-null  object
#  2   Temperature_C     302162 non-null  float64
#  3   Humidity_pct      302162 non-null  float64
#  4   Precipitation_mm  302162 non-null  float64
#  5   Wind_Speed_kmh    302161 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 13.8+ MB
# Location            0
# Date_Time           0
# Temperature_C       0
# Humidity_pct        0
# Precipitation_mm    0
# Wind_Speed_kmh      1
# dtype: int64

# %%
data['Date_Time'] = pd.to_datetime(data['Date_Time'])
data = data.dropna()
data = data.drop_duplicates()

# %%
plt.figure(figsize=(12,6))
plt.plot(data['Date_Time'], data['Temperature_C'])
plt.title("Temperature Trend Over Time")
plt.xlabel("Date_Time")
plt.ylabel("Temperature (°C)")
plt.show()
plt.rcParams['agg.path.chunksize'] = 10000
plt.rcParams['path.simplify_threshold'] = 0.5

# %%
sns.histplot(data['Temperature_C'], bins=30, kde=True)
plt.title("Temperature Distribution")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.bar(data['Date_Time'], data['Precipitation_mm'])
plt.title("Rainfall Over Time")
plt.xlabel("Date")
plt.ylabel("Rainfall (mm)")
plt.show()

# %%
sns.histplot(data['Temperature_C'], bins=30, kde=True)
plt.title("Temperature Distribution")
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.bar(data['Date_Time'], data['Precipitation_mm'])
plt.title("Rainfall Over Time")
plt.xlabel("Date")
plt.ylabel("Rainfall (mm)")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.select_dtypes(include=np.number).corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.countplot(x='Location', data=data)
plt.title("Location Frequency")
plt.xticks(rotation=90)
plt.show()

# %%
data['Month'] = data['Date_Time'].dt.month
monthly_avg = data.groupby('Month')['Temperature_C'].mean()

plt.figure(figsize=(10,5))
monthly_avg.plot(kind='bar', color='skyblue')
plt.title("Average Monthly Temperature")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.show()
